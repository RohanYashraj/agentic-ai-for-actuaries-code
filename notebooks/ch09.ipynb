# %% [markdown]
# # Chapter 9 — Agentic AI Foundations
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rohanyashraj/agentic-ai-for-actuaries-code/blob/main/notebooks/ch09.ipynb)
#
# Your first Agno agent, then the data quality case study.
#
# Companion notebook for [*Agentic AI for Actuaries*](https://github.com/rohanyashraj/agentic-ai-for-actuaries-code) — it clones the repository and runs the chapter's scripts, so the code you execute is exactly the code in the repo. All data is synthetic; see the repo README.

# %% [markdown]
# ## Setup
#
# Clone the repository and install the pinned dependencies (mirrors `pyproject.toml`).

# %%
import os
if not os.path.exists('/content/agentic-ai-for-actuaries-code'):
    # !git clone --depth 1 https://github.com/rohanyashraj/agentic-ai-for-actuaries-code.git /content/agentic-ai-for-actuaries-code
# %pip -q install "agno>=2.9,<3.0" "google-genai>=2.0" "pandas>=2.2" \
    "pypdf>=5.0" "chromadb>=1.0" "python-dotenv>=1.0" \
    "sqlalchemy>=2.0" "fastapi>=0.110"

# %% [markdown]
# ## API key
#
# The agent runs call Google Gemini. Get a free key at [aistudio.google.com/apikey](https://aistudio.google.com/apikey), then either add it as a Colab secret named `GOOGLE_API_KEY` (🔑 icon in the left sidebar — recommended) or paste it when prompted below.

# %%
import os
try:
    from google.colab import userdata
    os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')
except Exception:
    if not os.environ.get('GOOGLE_API_KEY'):
        import getpass
        os.environ['GOOGLE_API_KEY'] = getpass.getpass(
            'Paste your Google AI Studio API key: ')

# %%
# %cd /content/agentic-ai-for-actuaries-code/ch09_agentic_foundations

# %% [markdown]
# ## `01_column_agent.py` *(calls Gemini — needs the API key)*
#
# A minimal agent with a single tool that explains claims-triangle columns. The agent grounds its answer in the tool result.
#
# To view or edit the source, open `ch09_agentic_foundations/01_column_agent.py` in the file browser on the left.

# %%
# %run 01_column_agent.py

# %% [markdown]
# ## `02_data_quality_agent.py` *(calls Gemini — needs the API key)*
#
# A data quality agent with three checks — missing values, negative case reserves, reported-below-paid — run against the defect-seeded motor India triangle.
#
# To view or edit the source, open `ch09_agentic_foundations/02_data_quality_agent.py` in the file browser on the left.

# %%
# %run 02_data_quality_agent.py
